# %% [markdown]
# # AGEC best scores

# %% [markdown]
# We have evaluated the proposed system over two standard test sets QALB-2014 and QALB-2015 using the same tool in the first and the second AGEC shared task.  We reported precision, recall, and F1 score. The experimental results showed that our proposed model is outperforming all AGEC baselines as below:

# %% [markdown]
# # QALB-2014

# %%
! python2 ./m2Scripts/m2scorer.py ./m2Scripts/agec_output_2014.txt ./m2Scripts/QALB_test2014.m2
# Out:
# Precision   : 0.7906
# Recall      : 0.6579
# F_1.0       : 0.7182

# %% [markdown]
# # QALB-2015

# %%
! python2 ./m2Scripts/m2scorer.py ./m2Scripts/agec_output_2015.txt ./m2Scripts/Alj_QALB2015_test.m2
# Out:
# Precision   : 0.7836
# Recall      : 0.7043
# F_1.0       : 0.7418

# %% [markdown]
# The below figure shows the the performance of our proposed system as compared to the existing AGEC baselines.

# %% [markdown]
# ![fig3.png](attachment:fig3.png)
